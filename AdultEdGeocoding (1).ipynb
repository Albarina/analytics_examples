# %% [markdown]
# This notebook presents the tasks of reading, cleaning, and wrangling data for geocoding of current
# Adult Education locations in North Alabama.
#
# The business use case for this project stemmed from the need to identify potential service locations for additional Adult Education classes to be offered by a college. This information is necessary for the inclusion in the funding proposal under the future WIOA funding. Once the existing locations are identified, the team will start looking into the potential sites in the areas that are not covered by existing services, seek contacts and build relationships to solidify the proposed sites and identify the populations and their needs to complete the list of proposed services.

# %%
import pandas as pd
import numpy as np
import folium 
from folium.plugins import MarkerCluster

# %%
##Read the file and start looking into the existing format.
##The file is an excel file with 3 sheets.

# %%
xls = pd.ExcelFile('C:/Users/User/OneDrive/AdultEd/AdultEdCoordinates1.xlsx')
df1=pd.read_excel(xls,'Northeast')
df2=pd.read_excel(xls, 'WallaceStateHanceville')
df3=pd.read_excel(xls, 'Calhoun')

# %% [markdown]
# As evident from the above printout, the 3 different sheets have discrepancies: columns not named/not univormly named, unevent number of columnts, etc.
# Before merging the 3 sheets into one file, the following data cleaning tasks need to be performed:
# name columns, move the data from rows to columns (i.e. service types, county name),

# %%
#Cleaning out the first tab. There is inforamtion that needs to be moved ot the columns (County, Service).
#this information is included as table subheadings, i.e. row 1, 5, etc.

df1.head(25)
# Out:
#                 GED Class Locations and Schedules  \
# 0                                           Place
# 1     DeKalb County Class Locations and Schedules
# 2                        Fort Payne Career Center
# 3                                Ider High School
# 4                  Northeast AL Community College
# 5    Jackson County Class Locations and Schedules
# 6                  Northeast AL Community College
# 7               Scottsboro Adult Education Center
# 8   Marshall County Class Locations and Schedules
# 9                       Albertville Career Center
# 10                    Arab Adult Education Center
# 11            Guntersville Adult Education Center
# 12                  Snead State Community College
# 13                                            NaN
# 14                                            NaN
# 15              ESL Class Locations and Schedules
# 16                                          Place
# 17    DeKalb County Class Locations and Schedules
# 18                    Collinsville Public Library
# 19            Fort Payne Career Center, Suite 103
# 20                    Northeast Community College
# 21   Jackson County Class Locations and Schedules
# 22                         IMPACT Learning Center
# 23  Marshall County Class Locations and Schedules
# 24                            Boaz Public Library
#
#                                            Unnamed: 1  \
# 0                                             Address
# 1                                                 NaN
# 2   2100 Jordan Road SW Fort Payne, AL 35968 , Sui...
# 3                   1064 Crabapple Ln, Ider, AL 35981
# 4                  138 AL Hwy 35, Rainsville AL 35771
# 5                                                 NaN
# 6                  138 AL Hwy 35, Rainsville AL 35771
# 7         906 South Scott Street, Scottsboro AL 35768
# 8                                                 NaN
# 9                  5920 Hwy 431, Albertville AL 35950
# 10                153 South Main Street,Arab AL 35016
# 11  Finley Plaza  - 1415 Sunset Dr. Guntersville, ...
# 12                      400 W Mann Ave, Boaz AL 35957
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                            Address
# 17                                                NaN
# 18             151 Main Street, Collinsville AL 35961
# 19         2100 Jordan Road SW, Fort Payne AL 35968\n
# 20   138 AL Hwy 35 Rainsville, AL 35986 (Building GY)
# 21                                                NaN
# 22             23123 John T. Reid Parkway, Scottsboro
# 23                                                NaN
# 24                     404 Thomas Ave. Boaz, AL 35957
#
#                   Unnamed: 2  Unnamed: 3 Unnamed: 4
# 0                Coordinates         NaN        NaN
# 1                        NaN         NaN        NaN
# 2    34.4284804, -85.7609591         NaN        NaN
# 3      34.710593, -85.674351         NaN        NaN
# 4    34.4953643, -85.8492625         NaN        NaN
# 5                        NaN         NaN        NaN
# 6   34.4953643,  -85.8492625         NaN        NaN
# 7   34.6579641,  -86.0315051         NaN        NaN
# 8                        NaN         NaN        NaN
# 9    34.2637015,-86.1872064          NaN        NaN
# 10   34.3148534, -86.4953563         NaN        NaN
# 11   34.3525319, -86.3136567         NaN        NaN
# 12   34.1996251, -86.1682008         NaN        NaN
# 13                       NaN         NaN        NaN
# 14                       NaN         NaN
# 15                       NaN         NaN        NaN
# 16                       NaN         NaN        NaN
# 17                       NaN         NaN        NaN
# 18   34.2638688, -85.8604296         NaN        NaN
# 19   34.4284804, -85.7609591         NaN        NaN
# 20   34.4930659, -85.8457219         NaN        NaN
# 21                       NaN         NaN        NaN
# 22     34.649992, -86.028121         NaN        NaN
# 23                       NaN         NaN        NaN
# 24  34.2009218,  -86.1617569         NaN        NaN

# %%
#rename columns
df1.rename(columns={'GED Class Locations and Schedules': 'Location', 'Unnamed: 1': 'Address', 'Unnamed: 2': "Coordinates", 'Unnamed: 3':'County', 'Unnamed: 4': "Service"}, inplace=True)

# %%
df1.head(4)
# Out:
#                                       Location  \
# 0                                        Place
# 1  DeKalb County Class Locations and Schedules
# 2                     Fort Payne Career Center
# 3                             Ider High School
#
#                                              Address              Coordinates  \
# 0                                            Address              Coordinates
# 1                                                NaN                      NaN
# 2  2100 Jordan Road SW Fort Payne, AL 35968 , Sui...  34.4284804, -85.7609591
# 3                  1064 Crabapple Ln, Ider, AL 35981    34.710593, -85.674351
#
#    County Service
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN

# %%
#Adding values for the county column based on the available information 

conds = [(df1.index >= 0) & (df1.index <= 4), 
         (df1.index >=6) & (df1.index<=7),
         (df1.index>=9) & (df1.index<=12),
         (df1.index>=18) & (df1.index <=20),
         (df1.index==22),
         (df1.index>=24) & (df1.index<=26),
         (df1.index==32),
         (df1.index==34)
         
        ]

# Set up target values (in the same order as your conditions)
choices = ['Dekalb', 'Jackson', "Marshall", 'Dekalb','Jackson','Marshall', "Dekalb", "Marshall" ]

df1['County'] = np.select(conds, choices)

# %%
##Populate the Service column with the type of service, this information was included in rows, as a table subheading in the excel spreadsheet

df1.loc[2:12, 'Service'] = 'GED'
df1.loc[18:26, 'Service'] = "ESL"
df1.loc[31:34, "Service"] = 'Reading'

# %%
df1=df1.dropna(subset=['Service','Coordinates'])
#getting rid of the empty rows that existed in the table format

# %%
df1.head(35)
# Out:
#                                        Location  \
# 2                      Fort Payne Career Center
# 3                              Ider High School
# 4                Northeast AL Community College
# 6                Northeast AL Community College
# 7             Scottsboro Adult Education Center
# 9                     Albertville Career Center
# 10                  Arab Adult Education Center
# 11          Guntersville Adult Education Center
# 12                Snead State Community College
# 18                  Collinsville Public Library
# 19          Fort Payne Career Center, Suite 103
# 20                  Northeast Community College
# 22                       IMPACT Learning Center
# 24                          Boaz Public Library
# 25  Albertville ESL Crossroads Mall-Suite 23-24
# 26          Guntersville Adult Education Center
# 32                     Fort Payne Career Center
# 34          Guntersville Adult Education Center
#
#                                               Address  \
# 2   2100 Jordan Road SW Fort Payne, AL 35968 , Sui...
# 3                   1064 Crabapple Ln, Ider, AL 35981
# 4                  138 AL Hwy 35, Rainsville AL 35771
# 6                  138 AL Hwy 35, Rainsville AL 35771
# 7         906 South Scott Street, Scottsboro AL 35768
# 9                  5920 Hwy 431, Albertville AL 35950
# 10                153 South Main Street,Arab AL 35016
# 11  Finley Plaza  - 1415 Sunset Dr. Guntersville, ...
# 12                      400 W Mann Ave, Boaz AL 35957
# 18             151 Main Street, Collinsville AL 35961
# 19         2100 Jordan Road SW, Fort Payne AL 35968\n
# 20   138 AL Hwy 35 Rainsville, AL 35986 (Building GY)
# 22             23123 John T. Reid Parkway, Scottsboro
# 24                     404 Thomas Ave. Boaz, AL 35957
# 25                       5850 US Hwy 431, Albertville
# 26         *Finley Plaza 1415 Sunset Dr, Guntersville
# 32            2100 Jordan Rd SW, Fort Payne, AL 35968
# 34     Finley Plaza \n1415 Sunset Drive, Guntersville
#
#                  Coordinates    County  Service
# 2    34.4284804, -85.7609591    Dekalb      GED
# 3      34.710593, -85.674351    Dekalb      GED
# 4    34.4953643, -85.8492625    Dekalb      GED
# 6   34.4953643,  -85.8492625   Jackson      GED
# 7   34.6579641,  -86.0315051   Jackson      GED
# 9    34.2637015,-86.1872064   Marshall      GED
# 10   34.3148534, -86.4953563  Marshall      GED
# 11   34.3525319, -86.3136567  Marshall      GED
# 12   34.1996251, -86.1682008  Marshall      GED
# 18   34.2638688, -85.8604296    Dekalb      ESL
# 19   34.4284804, -85.7609591    Dekalb      ESL
# 20   34.4930659, -85.8457219    Dekalb      ESL
# 22     34.649992, -86.028121   Jackson      ESL
# 24  34.2009218,  -86.1617569  Marshall      ESL
# 25      34.263092, -86.18707  Marshall      ESL
# 26   34.3525319, -86.3136567  Marshall      ESL
# 32   34.4284804, -85.7609591    Dekalb  Reading
# 34   34.3525319, -86.3136567  Marshall  Reading

# %% [markdown]
# Cleaning out the second tab (df2)

# %%
df2.head(5)
# Out:
#                         Place                                   Address  \
# 0        WSCC GED Main Campus     801 Main St. NW Hanceville, AL 35077
# 1            ESL Main Campus      801 Main St. NW Hanceville, AL 35077
# 2      Alabama Career Center   1201 Katherine St. NW Cullman, AL 35055
# 3            Parkside School          12431 AL Hwy 69 Cullman, AL 35019
# 4  ESL – The Link of Cullman      708 9th Street, SE Cullman, AL 35055
#
#                Coordinates   County
# 0   34.0723219, -86.782038  Cullman
# 1   34.0723219, -86.782038  Cullman
# 2   34.1811138, -86.850139  Cullman
# 3  34.2682866,  -86.610495  Cullman
# 4    34.171699, -86.831159  Cullman

# %%
#Rennaming the columns for consistency across all the datasets
df2.rename(columns={'Place': 'Location'}, inplace=True)

# %%
#df2['Service']='GED'
#adding a Service column and assigning values

service= [(df2.index == 0), 
         (df2.index ==1),
         (df2.index>=2) & (df2.index<=3),
         (df2.index==4), 
         (df2.index==5),
         (df2.index==6),
          (df2.index==7),
          (df2.index==8),
          (df2.index>=9) & (df2.index<=10)
        ]

# Set up target values (in the same order as your conditions)
choices = ['GED', 'ESL', "GED", "ESL", "College Prep/ACT", 'ACE',"GED",'ESL','GED' ]

df2['Service'] = np.select(service, choices)

# %%
#making sure that there are no missing values/empty rows that may present the challenge for running the code
df2=df2.dropna()

# %%
df2.isna()
# Out:
#     Location  Address  Coordinates  County  Service
# 0      False    False        False   False    False
# 1      False    False        False   False    False
# 2      False    False        False   False    False
# 3      False    False        False   False    False
# 4      False    False        False   False    False
# 5      False    False        False   False    False
# 7      False    False        False   False    False
# 8      False    False        False   False    False
# 9      False    False        False   False    False
# 10     False    False        False   False    False

# %% [markdown]
# Moving on to the third tab, where the cleaning tasks are:
# 1. add a county column and county values
# 2. re-arrange the column order to match the rest of the data
# 3. rename the columns to match the rest of the data (e.g. 'Coordinates', not 'GPS')

# %%
df3.head(10)
# Out:
#   Unnamed: 0                             Location  \
# 0        GED                         Athens State
# 1        GED      Charlie Walker Community Center
# 2        GED         Community Action Partnership
# 3        GED               Calhoun Decatur Campus
# 4        GED               Decatur Youth Services
# 5        GED                  Good Shepard Church
# 6        GED  Hartselle Board of Education Office
# 7        GED             Huntsville Career Center
# 8        GED                   Madison County DHR
# 9        GED            Calhoun Huntsville Campus
#
#                                         Address  \
# 0                   300 N. Beaty St. Athens, AL
# 1            96 Schooner Trail, Toney, AL 35773
# 2  3516 Stringfield Rd NW, Huntsville, AL 35810
# 3                  6250 US-31, Tanner, AL 35671
# 4          1202 5th Ave SW B, Decatur, AL 35601
# 5                  3809 Spring Ave. Decatur, AL
# 6             305 College St. NE, Hartselle, AL
# 7                           2535 Sparkman Drive
# 8                              2206 Oakwood Ave
# 9                    102 Wynn Drive, Huntsville
#
#                                       GPS
# 0   34.80651388885214, -86.96435923863156
# 1   34.86312189397718, -86.60963390000002
# 2   34.77911438711254, -86.61832817116448
# 3   34.64814535933342, -86.94932091534214
# 4   34.58999468632191, -86.99437783068423
# 5   34.53576246724109, -87.00194826136843
# 6   34.44764870499331, -86.93126150794733
# 7   34.76356321935206, -86.59553058465788
# 8   34.75060996282883, -86.60239378867142
# 9  34.715902695256155, -86.65568211750839

# %%
##Assigning values to the new County column/df3

conds = [(df3.index == 0), 
         (df3.index >=1) & (df3.index<=2),
        (df3.index==3),
         (df3.index>=4) & (df3.index <=6),
         (df3.index>=7)& (df3.index<=17),
         (df3.index>=18) & (df3.index<=19),
         (df3.index>=20) & (df3.index<=22),
         (df3.index>=23) & (df3.index<=24)
         
        ]

# Set up target values (in the same order as your conditions)
choices = ['Limestone', 'Madison', "Limestone", 'Morgan','Madison','Limestone', "Madison", 'Limestone' ]

df3['County'] = np.select(conds, choices)

# %%
df3.head(10)
# Out:
#   Unnamed: 0                             Location  \
# 0        GED                         Athens State
# 1        GED      Charlie Walker Community Center
# 2        GED         Community Action Partnership
# 3        GED               Calhoun Decatur Campus
# 4        GED               Decatur Youth Services
# 5        GED                  Good Shepard Church
# 6        GED  Hartselle Board of Education Office
# 7        GED             Huntsville Career Center
# 8        GED                   Madison County DHR
# 9        GED            Calhoun Huntsville Campus
#
#                                         Address  \
# 0                   300 N. Beaty St. Athens, AL
# 1            96 Schooner Trail, Toney, AL 35773
# 2  3516 Stringfield Rd NW, Huntsville, AL 35810
# 3                  6250 US-31, Tanner, AL 35671
# 4          1202 5th Ave SW B, Decatur, AL 35601
# 5                  3809 Spring Ave. Decatur, AL
# 6             305 College St. NE, Hartselle, AL
# 7                           2535 Sparkman Drive
# 8                              2206 Oakwood Ave
# 9                    102 Wynn Drive, Huntsville
#
#                                       GPS     County
# 0   34.80651388885214, -86.96435923863156  Limestone
# 1   34.86312189397718, -86.60963390000002    Madison
# 2   34.77911438711254, -86.61832817116448    Madison
# 3   34.64814535933342, -86.94932091534214  Limestone
# 4   34.58999468632191, -86.99437783068423     Morgan
# 5   34.53576246724109, -87.00194826136843     Morgan
# 6   34.44764870499331, -86.93126150794733     Morgan
# 7   34.76356321935206, -86.59553058465788    Madison
# 8   34.75060996282883, -86.60239378867142    Madison
# 9  34.715902695256155, -86.65568211750839    Madison

# %%
#renaming the column names for consistency
df3.rename(columns={'Unnamed: 0': 'Service', 'GPS':'Coordinates'}, inplace=True)

#re-arranging the column order for consistency
neworder = ['Location','Address','Coordinates','County', 'Service']
df3=df3.reindex(columns=neworder)

# %%
##Merging the 3 dataframes
dta = pd.concat([df1, df2, df3])

# %%
dta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 2 to 24
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location     53 non-null     object
#  1   Address      53 non-null     object
#  2   Coordinates  53 non-null     object
#  3   County       53 non-null     object
#  4   Service      53 non-null     object
# dtypes: object(5)
# memory usage: 2.5+ KB

# %% [markdown]
# The next tasks:
# 1. prepping the coordinates for mapping
# 2. using Folium to create a map

# %%
dta[['lat', 'lon']] = dta['Coordinates'].str.split(' ', n=1, expand=True)

# %%
#adding the missing information for one of the entries
dta.loc[9, 'lat'] = '34.2637015'
dta.loc[9, 'lon'] = '-86.1872064'

# %%
dta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 2 to 24
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location     53 non-null     object
#  1   Address      53 non-null     object
#  2   Coordinates  53 non-null     object
#  3   County       53 non-null     object
#  4   Service      53 non-null     object
#  5   lat          53 non-null     object
#  6   lon          53 non-null     object
# dtypes: object(7)
# memory usage: 4.6+ KB

# %%
#removing the unnecessary semicolon from the latitude column
dta['lat'].replace(',','', regex=True, inplace=True)

# %%
dta.dtypes
# Out:
# Location       object
# Address        object
# Coordinates    object
# County         object
# Service        object
# lat            object
# lon            object
# dtype: object

# %%
#recoding the values into the numeric format so that the code would run
dta['lat'] = dta['lat'].apply(pd.to_numeric, errors='coerce')
dta['lon'] =dta['lon'].apply(pd.to_numeric, errors='coerce')

# %%
aemap = folium.Map(location=dta[["lat", "lon"]].mean().to_list(), zoom_start=10)

marker_cluster = MarkerCluster().add_to(aemap)
 
for i,r in dta.iterrows():
    location = (r["lat"], r["lon"])
    folium.Marker(location=location,
                      popup = r['Service'],
                      tooltip=r['Service'])\
    .add_to(marker_cluster)
# display the map
aemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_547cdfbef9f3ba904de7478582c2065a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_547cdfbef9f3ba904de7478582c2065a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_547cdfbef9f3ba904de7478582c2065a = L.map(
#                 &quot;map_547cdfbef9f3ba904de7478582c2065a&quot;,
#                 {
#                     center: [34.479645297335516, -86.47804464218224],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cb31fc953c4760945951c213c3734fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4cb31fc953c4760945951c213c3734fd.addTo(map_547cdfbef9f3ba904de7478582c2065a);
#
#
#             var marker_cluster_5b8734a73b2136f059f7667991c03c99 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_34c62e5d72c07c368889385b8fef6850 = L.marker(
#                 [34.4284804, -85.7609591],
#                 {}
#             ).addTo(marker_cluster_5b8734a73b2136f059f7667991c03c99);
#
#
#         var popup_994c1f3bcd22788b3dc162b73459f3ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ee7fe393b8c78bd3d0147ca35000439 = $(`&lt;div id=&quot;html_3ee7fe393b8c78bd3d0147ca35000439&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GED&lt;/div&gt;`)[0];
#                 popup_994c1f3bcd22788b3dc162b73459f3ed.setContent(html_3ee7fe393b8c78bd3d0147ca35000439);
#
#
#
#         marker_34c62e5d72c07c368889385b8fef6850.bindPopup(popup_994c1f3bcd22788b3dc162b73459f3ed)
#         ;
#
#
#
#
#             marker_34c62e5d72c07c368889385b8fef6850.bindTooltip(
#                 `&lt;div&gt;
#                      GED
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a8ebd1f3ef8f6614743d17d603829879 = L.marker(
#                 [34.710592999999996, -85.674351],
#                 {}
#             ).addTo(marker_cluster_5b8734a73b2136f059f7667991c03c99);
#
#
#         var popup_f0276d22e58f5305337c7e8f9ef49eef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e334e88db84e26a8feb895fa3ac9cf98 = $(`&lt;div id=&quot;html_e334e88db84e26a8feb895fa3ac9cf98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GED&lt;/div&gt;`)[0];
#                 popup_f0276d22e58f5305337c7e8f9ef49eef.setContent(html_e334e88db84e26a8feb895fa3ac9cf98);
#
#
#
#         marker_a8ebd1f3ef8f6614743d17d603829879.bindPopup(popup_f0276d22e58f5305337c7e8f9ef49eef)
#         ;
#
#
#
#
#             marker_a8ebd1f3ef8f6614743d17d603829879.bindTooltip(
#                 `&lt;div&gt;
#                      GED
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_07101a5b22c0ef94e5ce3ae86c7cec44 = L.marker(
#                 [34.4953643, -85.8492625],
#                 {}
#             ).addTo(marker_cluster_5b8734a73b2136f059f7667991c03c99);
#
#
#         var popup_9c02e81612151888bd756adaec0fe1b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_912195b1383178be7e3319cd3704f739 = $(`&lt;div id=&quot;html_912195b1383178be7e3319cd3704f739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GED&lt;/div&gt;`)[0];
#                 popup_9c02e81612151888bd756adaec0fe1b8.setContent(html_912195b1383178be7e3319cd3704f739);
#
#
#
#         marker_07101a5b22c0ef94e5ce3ae86c7cec44.bindPopup(popup_9c02e81612151888bd756adaec0fe1b8)
#         ;
#
#
#
#
#             marker_07101a5b22c0ef94e5ce3ae86c7cec44.bindTooltip(
#                 `&lt;div&gt;
#                      GED
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_961a8db520860443d3830c5e27d0907a = L.marker(
#                 [34.4953643, -85.8492625],
#                 {}
#             ).addTo(marker_cluster_5b8734a73b2136f059f7667991c03c99);
#
#
#         var popup_c37f6147ab0b13599a3c0f9440e1cdf4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8ac9ca9537c5784e82be015b832b356 = $(`&lt;div id=&quot;html_a8ac9ca9537c5784e82be015b832b356&quot; style=&quot;width: 100.0%

# %% [markdown]
# The map shows the pockets of service locations. The grant team can identify the areas without service and focus on researching the needs and possible service locations.
